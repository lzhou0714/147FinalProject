# %% [markdown]
# ## CNN-SeqSelfAttention

# %% [markdown]
# #### This notebook was inspired to Tonmoy with some attempts to tune by us

# %% [markdown]
# ## (i) Importing the necessary packages

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
from keras_self_attention import SeqSelfAttention

from keras import layers
from keras.models import Sequential,Model
from keras.layers import Dense, Activation, Flatten,Dropout, MultiHeadAttention, Bidirectional
from keras.layers import Conv2D,LSTM,BatchNormalization,MaxPooling2D,Reshape, LayerNormalization,GlobalAveragePooling1D,GlobalAveragePooling2D
from keras.utils import to_categorical
import matplotlib.pyplot as plt

tf.compat.v1.random.set_random_seed(3)

# %% [markdown]
# ## (ii) Preprocessing the dataset and preparing the training, validation, and test datasets

# %%
def data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,500)
    X = X[:,:,0:500]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape)
    return total_X,total_y

# %%
## Loading the dataset


X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769


## Random splitting and reshaping the data
# First generating the training and validation indices using random splitting

ind_valid = np.random.choice(2115, 375, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(X_train, X_valid) = X_train_valid[ind_train], X_train_valid[ind_valid] 
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]


## Preprocessing the dataset
x_train,y_train = data_prep(X_train,y_train,2,2,True)
x_valid,y_valid = data_prep(X_valid,y_valid,2,2,True)
X_test_prep,y_test_prep = data_prep(X_test,y_test,2,2,True)


print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)
print('Shape of testing set:',X_test_prep.shape)
print('Shape of testing labels:',y_test_prep.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test_prep, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)

keras.backend.clear_session()
# Out:
# Shape of X after trimming: (1740, 22, 500)
# Shape of X after maxpooling: (1740, 22, 250)
# Shape of X after averaging+noise and concatenating: (3480, 22, 250)
# Shape of X after subsampling and concatenating: (6960, 22, 250)
# Shape of X after trimming: (375, 22, 500)
# Shape of X after maxpooling: (375, 22, 250)
# Shape of X after averaging+noise and concatenating: (750, 22, 250)
# Shape of X after subsampling and concatenating: (1500, 22, 250)
# Shape of X after trimming: (443, 22, 500)
# Shape of X after maxpooling: (443, 22, 250)
# Shape of X after averaging+noise and concatenating: (886, 22, 250)
# Shape of X after subsampling and concatenating: (1772, 22, 250)
# Shape of training set: (6960, 22, 250)
# Shape of validation set: (1500, 22, 250)
# Shape of training labels: (6960,)
# Shape of validation labels: (1500,)
# Shape of testing set: (1772, 22, 250)
# Shape of testing labels: (1772,)
# Shape of training labels after categorical conversion: (6960, 4)
# Shape of validation labels after categorical conversion: (1500, 4)
# Shape of test labels after categorical conversion: (1772, 4)
# Shape of training set after adding width info: (6960, 22, 250, 1)
# Shape of validation set after adding width info: (1500, 22, 250, 1)
# Shape of test set after adding width info: (1772, 22, 250, 1)
# Shape of training set after dimension reshaping: (6960, 250, 1, 22)
# Shape of validation set after dimension reshaping: (1500, 250, 1, 22)
# Shape of test set after dimension reshaping: (1772, 250, 1, 22)

# %% [markdown]
# ## (iii)(CNN-LSTM) Defining the architecture of the hybrid CNN-LSTM model

# %%
# Building the CNN model using functional class
def build_model():
# models = []

    n_frames = 250
    n_channels = 22
    # Conv. block 1
    In1 = keras.Input(shape =(250,1,22) )
    c1 = Conv2D(filters=30, kernel_size=(11,1), padding='same', activation='swish')(In1)
    p1 =  MaxPooling2D(pool_size=(4,1), padding='same')(c1) # Read the keras documentation
    b1 = BatchNormalization()(p1)
    d1 = Dropout(0.8)(b1)

    # Conv. block 2
    c2 = Conv2D(filters=60, kernel_size=(9,1), padding='same', activation='swish')(d1)
    p2 =  MaxPooling2D(pool_size=(4,1), padding='same')(c2) # Read the keras documentation
    b2 = BatchNormalization()(p2)
    d2 = Dropout(0.7)(b2)

    # Conv. block 3
    c3 = Conv2D(filters=120, kernel_size=(5,1), padding='same', activation='gelu')(d2)
    p3 =  MaxPooling2D(pool_size=(4,1), padding='same')(c3) # Read the keras documentation
    b3 = BatchNormalization()(p3)
    d3 = Dropout(0.6)(b3)

    c4 = Conv2D(filters=240, kernel_size=(3,1), padding='same', activation='gelu')(d3)
    p4 =  MaxPooling2D(pool_size=(4,1), padding='same')(c4) # Read the keras documentation
    b4 = BatchNormalization()(p4)
    d4 = Dropout(0.5)(b4)

    # self attention block
    selfatt = tf.squeeze(d4, axis=2)
    selfatt = SeqSelfAttention(attention_activation='gelu')(selfatt)
    selfatt = GlobalAveragePooling1D()(selfatt)
    
    # Add fully connected layers
    fc1 = Dense(64, activation='relu')(selfatt)
    fc1_dropout = Dropout(rate=0.5)(fc1)
    fc2 = Dense(4, activation='softmax')(fc1_dropout)

    # Define the final model
    final_model = Model(inputs=In1, outputs=[fc2])

    # # Printing the model summary
    final_model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])
    final_model.summary()
    return final_model

# %% [markdown]
# ## (iv)(CNN-LSTM) Defining the hyperparameters of the hybrid CNN-LSTM model

# %%
# Model parameters
epochs = 300
initial_learning_rate = 1e-3
decay_steps = 1000
decay_rate = 0.99

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=decay_steps,
    decay_rate=decay_rate
)

optimizer = keras.optimizers.Adam(learning_rate=lr_schedule)

# %% [markdown]
# ## (v)Attention at the end

# %%
# Compiling the model
keras.backend.clear_session()

# Training and validating the model

batch_sizes = [32,64,128]
import matplotlib.pyplot as plt

hybrid_cnn_lstm_model = build_model()
# Compiling the model
hybrid_cnn_lstm_model.compile(loss='categorical_crossentropy',
               optimizer=optimizer,
               metrics=['accuracy'])

# Training and validating the model
acc = 0.73
class myCallback(tf.keras.callbacks.Callback):
	def on_epoch_end(self, epoch, logs={}):
		if((logs.get('val_accuracy') > acc)):
			print("\nval accuracy high enough and difference between train and test is greater than %2.2f%%, so stopping training!!" %(acc*100))
			self.model.stop_training = True

# Instantiate a callback object
callback = myCallback()
# callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
hybrid_cnn_lstm_model_results = hybrid_cnn_lstm_model.fit(x_train,
                y_train,
                batch_size=32,
                epochs=epochs,
                validation_data=(x_valid, y_valid), 
                verbose=True,
                callbacks = [callback]
                )
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 250, 1, 22)]      0
#
#  conv2d (Conv2D)             (None, 250, 1, 30)        7290
#
#  max_pooling2d (MaxPooling2D  (None, 63, 1, 30)        0
#  )
#
#  batch_normalization (BatchN  (None, 63, 1, 30)        120
#  ormalization)
#
#  dropout (Dropout)           (None, 63, 1, 30)         0
#
#  conv2d_1 (Conv2D)           (None, 63, 1, 60)         16260
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 1, 60)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 16, 1, 60)        240
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 16, 1, 60)         0
#
#  conv2d_2 (Conv2D)           (None, 16, 1, 120)        36120
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 1, 120)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 4, 1, 120)        480
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 4, 1, 120)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 1, 240)         86640
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 240)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 1, 1, 240)        960
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 1, 1, 240)         0
#
#  tf.compat.v1.squeeze (TFOpL  (None, 1, 240)           0
#  ambda)
#
#  seq_self_attention (SeqSelf  (None, 1, 240)           15425
#  Attention)
#
#  global_average_pooling1d (G  (None, 240)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 64)                15424
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 179,219
# Trainable params: 178,319
# Non-trainable params: 900
# _________________________________________________________________
# Epoch 1/300
# 218/218 [==============================] - 4s 12ms/step - loss: 2.1580 - accuracy: 0.2457 - val_loss: 1.4776 - val_accuracy: 0.2533
# Epoch 2/300
# 218/218 [==============================] - 2s 11ms/step - loss: 1.6214 - accuracy: 0.2529 - val_loss: 1.4097 - val_accuracy: 0.2400
# Epoch 3/300
# 218/218 [==============================] - 2s 11ms/step - loss: 1.4828 - accuracy: 0.2593 - val_loss: 1.3950 - val_accuracy: 0.2400
# Epoch 4/300
# 218/218 [==============================] - 3s 12ms/step - loss: 1.4206 - accuracy: 0.2693 - val_loss: 1.4001 - val_accuracy: 0.2400
# Epoch 5/300
# 218/218 [==============================] - 3s 12ms/step - loss: 1.4063 - accuracy: 0.2655 - val_loss: 1.3947 - val_accuracy: 0.2520
# Epoch 6/300
# 218/218 [==============================] - 2s 11ms/step - loss: 1.3901 - accuracy: 0.2760 - val_loss: 1.3990 - val_accuracy: 0.2520
# Epoch 7/300
# 218/218 [==============================] - 2s 11ms/step - loss: 1.3871 - accuracy: 0.2731 - val_loss: 1.3927 - val_accuracy: 0.2500
# Epoch 8/300
# 218/218 [==============================] - 3s 11ms/step - loss: 1.3818 - accuracy: 0.2849 - val_loss: 1.3959 - val_accuracy: 0.2400
# Epoch 9/300
# 218/218 [==============================] - 3s 13ms/step - loss: 1.3811 - accuracy: 0.2741 - val_loss: 1.3924 - val_accuracy: 0.2540
# Epoch 10/300
# 218/218 [==============================] - 2s 11ms/step - loss: 1.3787 - accuracy: 0.2730 - val_loss: 1.3995 - val_accuracy: 0.2400
# Epoch 11/300
# 218/218 [==============================] - 3s 12ms/step - loss: 1.3785 - accuracy: 0.2858 - val_loss: 1.3866 - val_accuracy: 0.2633
# Epoch 12/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3700 - accuracy: 0.2973 - val_loss: 1.3877 - val_accuracy: 0.2607
# Epoch 13/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3630 - accuracy: 0.3118 - val_loss: 1.3992 - val_accuracy: 0.2593
# Epoch 14/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3617 - accuracy: 0.3034 - val_loss: 1.3742 - val_accuracy: 0.3513
# Epoch 15/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3540 - accuracy: 0.3188 - val_loss: 1.3721 - val_accuracy: 0.3513
# Epoch 16/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3503 - accuracy: 0.3228 - val_loss: 1.3620 - val_accuracy: 0.2980
# Epoch 17/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3325 - accuracy: 0.3326 - val_loss: 1.3670 - val_accuracy: 0.2993
# Epoch 18/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3226 - accuracy: 0.3519 - val_loss: 1.3324 - val_accuracy: 0.3527
# Epoch 19/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3105 - accuracy: 0.3638 - val_loss: 1.2951 - val_accuracy: 0.3820
# Epoch 20/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2998 - accuracy: 0.3704 - val_loss: 1.2903 - val_accuracy: 0.4033
# Epoch 21/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2868 - accuracy: 0.3864 - val_loss: 1.2648 - val_accuracy: 0.4167
# Epoch 22/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.2780 - accuracy: 0.4024 - val_loss: 1.2961 - val_accuracy: 0.3900
# Epoch 23/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2743 - accuracy: 0.4106 - val_loss: 1.2603 - val_accuracy: 0.4420
# Epoch 24/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2602 - accuracy: 0.4082 - val_loss: 1.2474 - val_accuracy: 0.4120
# Epoch 25/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2560 - accuracy: 0.4121 - val_loss: 1.2627 - val_accuracy: 0.4073
# Epoch 26/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2501 - accuracy: 0.4207 - val_loss: 1.2363 - val_accuracy: 0.4447
# Epoch 27/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2500 - accuracy: 0.4184 - val_loss: 1.2361 - val_accuracy: 0.4500
# Epoch 28/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2308 - accuracy: 0.4309 - val_loss: 1.2373 - val_accuracy: 0.4493
# Epoch 29/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2417 - accuracy: 0.4216 - val_loss: 1.2351 - val_accuracy: 0.4293
# Epoch 30/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2279 - accuracy: 0.4428 - val_loss: 1.2133 - val_accuracy: 0.4467
# Epoch 31/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2231 - accuracy: 0.4445 - val_loss: 1.2238 - val_accuracy: 0.4327
# Epoch 32/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2153 - accuracy: 0.4514 - val_loss: 1.2060 - val_accuracy: 0.4480
# Epoch 33/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2085 - accuracy: 0.4421 - val_loss: 1.2240 - val_accuracy: 0.4427
# Epoch 34/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1929 - accuracy: 0.4670 - val_loss: 1.1791 - val_accuracy: 0.4827
# Epoch 35/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1940 - accuracy: 0.4688 - val_loss: 1.1732 - val_accuracy: 0.4973
# Epoch 36/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1863 - accuracy: 0.4691 - val_loss: 1.1806 - val_accuracy: 0.4840
# Epoch 37/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1756 - accuracy: 0.4711 - val_loss: 1.2028 - val_accuracy: 0.4813
# Epoch 38/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1759 - accuracy: 0.4713 - val_loss: 1.1590 - val_accuracy: 0.5167
# Epoch 39/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1714 - accuracy: 0.4813 - val_loss: 1.1592 - val_accuracy: 0.5107
# Epoch 40/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1700 - accuracy: 0.4803 - val_loss: 1.1525 - val_accuracy: 0.5007
# Epoch 41/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1590 - accuracy: 0.4868 - val_loss: 1.1238 - val_accuracy: 0.5247
# Epoch 42/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1569 - accuracy: 0.4930 - val_loss: 1.1437 - val_accuracy: 0.5300
# Epoch 43/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1492 - accuracy: 0.4920 - val_loss: 1.1264 - val_accuracy: 0.5247
# Epoch 44/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1454 - accuracy: 0.4943 - val_loss: 1.1090 - val_accuracy: 0.5520
# Epoch 45/300
# 218/218 [==============================] - 4s 18ms/step - loss: 1.1390 - accuracy: 0.4978 - val_loss: 1.1116 - val_accuracy: 0.5613
# Epoch 46/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1274 - accuracy: 0.5046 - val_loss: 1.0927 - val_accuracy: 0.5473
# Epoch 47/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1162 - accuracy: 0.5185 - val_loss: 1.0760 - val_accuracy: 0.5927
# Epoch 48/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1203 - accuracy: 0.5187 - val_loss: 1.0892 - val_accuracy: 0.5913
# Epoch 49/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1056 - accuracy: 0.5203 - val_loss: 1.0806 - val_accuracy: 0.5600
# Epoch 50/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0941 - accuracy: 0.5362 - val_loss: 1.0513 - val_accuracy: 0.5873
# Epoch 51/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1042 - accuracy: 0.5313 - val_loss: 1.0794 - val_accuracy: 0.6027
# Epoch 52/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0943 - accuracy: 0.5325 - val_loss: 1.0848 - val_accuracy: 0.5673
# Epoch 53/300
# 218/218 [==============================] - 3s 13ms/step - loss: 1.0981 - accuracy: 0.5318 - val_loss: 1.0875 - val_accuracy: 0.5767
# Epoch 54/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0873 - accuracy: 0.5376 - val_loss: 1.0443 - val_accuracy: 0.5867
# Epoch 55/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0761 - accuracy: 0.5450 - val_loss: 1.0467 - val_accuracy: 0.5813
# Epoch 56/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0742 - accuracy: 0.5397 - val_loss: 1.0376 - val_accuracy: 0.6027
# Epoch 57/300
# 218/218 [==============================] - 3s 13ms/step - loss: 1.0629 - accuracy: 0.5497 - val_loss: 1.0140 - val_accuracy: 0.6180
# Epoch 58/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0567 - accuracy: 0.5603 - val_loss: 1.0072 - val_accuracy: 0.6087
# Epoch 59/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0581 - accuracy: 0.5611 - val_loss: 1.0268 - val_accuracy: 0.6020
# Epoch 60/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0531 - accuracy: 0.5658 - val_loss: 1.0199 - val_accuracy: 0.6000
# Epoch 61/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0534 - accuracy: 0.5559 - val_loss: 1.0083 - val_accuracy: 0.6127
# Epoch 62/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0549 - accuracy: 0.5552 - val_loss: 1.0115 - val_accuracy: 0.6173
# Epoch 63/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0573 - accuracy: 0.5608 - val_loss: 1.0247 - val_accuracy: 0.5980
# Epoch 64/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0347 - accuracy: 0.5672 - val_loss: 1.0039 - val_accuracy: 0.6147
# Epoch 65/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0324 - accuracy: 0.5634 - val_loss: 0.9944 - val_accuracy: 0.6107
# Epoch 66/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0416 - accuracy: 0.5649 - val_loss: 0.9801 - val_accuracy: 0.6347
# Epoch 67/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0320 - accuracy: 0.5754 - val_loss: 0.9754 - val_accuracy: 0.6380
# Epoch 68/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0279 - accuracy: 0.5694 - val_loss: 0.9765 - val_accuracy: 0.6187
# Epoch 69/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0230 - accuracy: 0.5786 - val_loss: 0.9793 - val_accuracy: 0.6120
# Epoch 70/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0220 - accuracy: 0.5809 - val_loss: 0.9692 - val_accuracy: 0.6347
# Epoch 71/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0221 - accuracy: 0.5757 - val_loss: 0.9825 - val_accuracy: 0.6293
# Epoch 72/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0192 - accuracy: 0.5876 - val_loss: 0.9738 - val_accuracy: 0.6453
# Epoch 73/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0140 - accuracy: 0.5806 - val_loss: 0.9659 - val_accuracy: 0.6407
# Epoch 74/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0105 - accuracy: 0.5829 - val_loss: 0.9485 - val_accuracy: 0.6393
# Epoch 75/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0094 - accuracy: 0.5836 - val_loss: 0.9571 - val_accuracy: 0.6293
# Epoch 76/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0052 - accuracy: 0.5819 - val_loss: 0.9381 - val_accuracy: 0.6327
# Epoch 77/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0134 - accuracy: 0.5790 - val_loss: 0.9492 - val_accuracy: 0.6320
# Epoch 78/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9889 - accuracy: 0.5891 - val_loss: 0.9497 - val_accuracy: 0.6393
# Epoch 79/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9817 - accuracy: 0.6022 - val_loss: 0.9283 - val_accuracy: 0.6427
# Epoch 80/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9819 - accuracy: 0.5938 - val_loss: 0.9492 - val_accuracy: 0.6213
# Epoch 81/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9927 - accuracy: 0.5940 - val_loss: 0.9285 - val_accuracy: 0.6480
# Epoch 82/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9784 - accuracy: 0.6020 - val_loss: 0.9237 - val_accuracy: 0.6360
# Epoch 83/300
# 218/218 [==============================] - 4s 17ms/step - loss: 0.9650 - accuracy: 0.6086 - val_loss: 0.9178 - val_accuracy: 0.6353
# Epoch 84/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9848 - accuracy: 0.5908 - val_loss: 0.9011 - val_accuracy: 0.6527
# Epoch 85/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9792 - accuracy: 0.6000 - val_loss: 0.9231 - val_accuracy: 0.6507
# Epoch 86/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9692 - accuracy: 0.6108 - val_loss: 0.9007 - val_accuracy: 0.6560
# Epoch 87/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9656 - accuracy: 0.6024 - val_loss: 0.9042 - val_accuracy: 0.6493
# Epoch 88/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9589 - accuracy: 0.6128 - val_loss: 0.9256 - val_accuracy: 0.6273
# Epoch 89/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9653 - accuracy: 0.6039 - val_loss: 0.9439 - val_accuracy: 0.6307
# Epoch 90/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9660 - accuracy: 0.6132 - val_loss: 0.9027 - val_accuracy: 0.6487
# Epoch 91/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9599 - accuracy: 0.6093 - val_loss: 0.8966 - val_accuracy: 0.6640
# Epoch 92/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9641 - accuracy: 0.6108 - val_loss: 0.9098 - val_accuracy: 0.6613
# Epoch 93/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9608 - accuracy: 0.6062 - val_loss: 0.9094 - val_accuracy: 0.6447
# Epoch 94/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9431 - accuracy: 0.6181 - val_loss: 0.8987 - val_accuracy: 0.6613
# Epoch 95/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9610 - accuracy: 0.6111 - val_loss: 0.9081 - val_accuracy: 0.6420
# Epoch 96/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9482 - accuracy: 0.6175 - val_loss: 0.8956 - val_accuracy: 0.6647
# Epoch 97/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9445 - accuracy: 0.6187 - val_loss: 0.9014 - val_accuracy: 0.6340
# Epoch 98/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9400 - accuracy: 0.6217 - val_loss: 0.9011 - val_accuracy: 0.6467
# Epoch 99/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9470 - accuracy: 0.6230 - val_loss: 0.8851 - val_accuracy: 0.6653
# Epoch 100/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9349 - accuracy: 0.6216 - val_loss: 0.8845 - val_accuracy: 0.6847
# Epoch 101/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9458 - accuracy: 0.6136 - val_loss: 0.9004 - val_accuracy: 0.6400
# Epoch 102/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9290 - accuracy: 0.6263 - val_loss: 0.8814 - val_accuracy: 0.6607
# Epoch 103/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9367 - accuracy: 0.6198 - val_loss: 0.8843 - val_accuracy: 0.6500
# Epoch 104/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9385 - accuracy: 0.6221 - val_loss: 0.8747 - val_accuracy: 0.6627
# Epoch 105/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9255 - accuracy: 0.6264 - val_loss: 0.8649 - val_accuracy: 0.6720
# Epoch 106/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9264 - accuracy: 0.6345 - val_loss: 0.8767 - val_accuracy: 0.6573
# Epoch 107/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9109 - accuracy: 0.6310 - val_loss: 0.8753 - val_accuracy: 0.6780
# Epoch 108/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9195 - accuracy: 0.6339 - val_loss: 0.8560 - val_accuracy: 0.6900
# Epoch 109/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9122 - accuracy: 0.6336 - val_loss: 0.8733 - val_accuracy: 0.6740
# Epoch 110/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9048 - accuracy: 0.6408 - val_loss: 0.8690 - val_accuracy: 0.6847
# Epoch 111/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9079 - accuracy: 0.6348 - val_loss: 0.8622 - val_accuracy: 0.6807
# Epoch 112/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9081 - accuracy: 0.6365 - val_loss: 0.8677 - val_accuracy: 0.6773
# Epoch 113/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8920 - accuracy: 0.6440 - val_loss: 0.8574 - val_accuracy: 0.6780
# Epoch 114/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9050 - accuracy: 0.6352 - val_loss: 0.8460 - val_accuracy: 0.6820
# Epoch 115/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9117 - accuracy: 0.6402 - val_loss: 0.8558 - val_accuracy: 0.6920
# Epoch 116/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9056 - accuracy: 0.6425 - val_loss: 0.8405 - val_accuracy: 0.6920
# Epoch 117/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8907 - accuracy: 0.6384 - val_loss: 0.8395 - val_accuracy: 0.6913
# Epoch 118/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8882 - accuracy: 0.6415 - val_loss: 0.8455 - val_accuracy: 0.6940
# Epoch 119/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8998 - accuracy: 0.6415 - val_loss: 0.8439 - val_accuracy: 0.6960
# Epoch 120/300
# 218/218 [==============================] - 4s 19ms/step - loss: 0.8948 - accuracy: 0.6438 - val_loss: 0.8432 - val_accuracy: 0.6780
# Epoch 121/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9015 - accuracy: 0.6381 - val_loss: 0.8417 - val_accuracy: 0.6853
# Epoch 122/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9000 - accuracy: 0.6386 - val_loss: 0.8416 - val_accuracy: 0.6873
# Epoch 123/300
# 218/218 [==============================] - 4s 17ms/step - loss: 0.8765 - accuracy: 0.6569 - val_loss: 0.8322 - val_accuracy: 0.6900
# Epoch 124/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8889 - accuracy: 0.6467 - val_loss: 0.8637 - val_accuracy: 0.6873
# Epoch 125/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8867 - accuracy: 0.6486 - val_loss: 0.8312 - val_accuracy: 0.7000
# Epoch 126/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8905 - accuracy: 0.6476 - val_loss: 0.8293 - val_accuracy: 0.6940
# Epoch 127/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8937 - accuracy: 0.6428 - val_loss: 0.8472 - val_accuracy: 0.6693
# Epoch 128/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8807 - accuracy: 0.6438 - val_loss: 0.8492 - val_accuracy: 0.6913
# Epoch 129/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8717 - accuracy: 0.6382 - val_loss: 0.8435 - val_accuracy: 0.6860
# Epoch 130/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8857 - accuracy: 0.6478 - val_loss: 0.8475 - val_accuracy: 0.6987
# Epoch 131/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8731 - accuracy: 0.6562 - val_loss: 0.8591 - val_accuracy: 0.6700
# Epoch 132/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8790 - accuracy: 0.6437 - val_loss: 0.8522 - val_accuracy: 0.6920
# Epoch 133/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8721 - accuracy: 0.6552 - val_loss: 0.8342 - val_accuracy: 0.6880
# Epoch 134/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8762 - accuracy: 0.6563 - val_loss: 0.8313 - val_accuracy: 0.6900
# Epoch 135/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8578 - accuracy: 0.6575 - val_loss: 0.8378 - val_accuracy: 0.6913
# Epoch 136/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8831 - accuracy: 0.6484 - val_loss: 0.8357 - val_accuracy: 0.6820
# Epoch 137/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8795 - accuracy: 0.6506 - val_loss: 0.8255 - val_accuracy: 0.6947
# Epoch 138/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8673 - accuracy: 0.6468 - val_loss: 0.8235 - val_accuracy: 0.7053
# Epoch 139/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8655 - accuracy: 0.6631 - val_loss: 0.8232 - val_accuracy: 0.6933
# Epoch 140/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8719 - accuracy: 0.6504 - val_loss: 0.8306 - val_accuracy: 0.6893
# Epoch 141/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8708 - accuracy: 0.6586 - val_loss: 0.8295 - val_accuracy: 0.6927
# Epoch 142/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8603 - accuracy: 0.6614 - val_loss: 0.8484 - val_accuracy: 0.6887
# Epoch 143/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8709 - accuracy: 0.6596 - val_loss: 0.8492 - val_accuracy: 0.6813
# Epoch 144/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8566 - accuracy: 0.6619 - val_loss: 0.8306 - val_accuracy: 0.7000
# Epoch 145/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8616 - accuracy: 0.6644 - val_loss: 0.8157 - val_accuracy: 0.7007
# Epoch 146/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8536 - accuracy: 0.6599 - val_loss: 0.8197 - val_accuracy: 0.6933
# Epoch 147/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8737 - accuracy: 0.6606 - val_loss: 0.8364 - val_accuracy: 0.7033
# Epoch 148/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8646 - accuracy: 0.6569 - val_loss: 0.8194 - val_accuracy: 0.6980
# Epoch 149/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8666 - accuracy: 0.6556 - val_loss: 0.8104 - val_accuracy: 0.7013
# Epoch 150/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8543 - accuracy: 0.6638 - val_loss: 0.8172 - val_accuracy: 0.7007
# Epoch 151/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8539 - accuracy: 0.6599 - val_loss: 0.8262 - val_accuracy: 0.6967
# Epoch 152/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8605 - accuracy: 0.6565 - val_loss: 0.8194 - val_accuracy: 0.7033
# Epoch 153/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8554 - accuracy: 0.6678 - val_loss: 0.8239 - val_accuracy: 0.7013
# Epoch 154/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8547 - accuracy: 0.6589 - val_loss: 0.8273 - val_accuracy: 0.6893
# Epoch 155/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8652 - accuracy: 0.6635 - val_loss: 0.8249 - val_accuracy: 0.7033
# Epoch 156/300
# 218/218 [==============================] - 4s 16ms/step - loss: 0.8430 - accuracy: 0.6625 - val_loss: 0.7914 - val_accuracy: 0.7127
# Epoch 157/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8453 - accuracy: 0.6704 - val_loss: 0.8064 - val_accuracy: 0.7040
# Epoch 158/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.8363 - accuracy: 0.6657 - val_loss: 0.8053 - val_accuracy: 0.7107
# Epoch 159/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8612 - accuracy: 0.6655 - val_loss: 0.8049 - val_accuracy: 0.7027
# Epoch 160/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8350 - accuracy: 0.6621 - val_loss: 0.7981 - val_accuracy: 0.7053
# Epoch 161/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8379 - accuracy: 0.6674 - val_loss: 0.8026 - val_accuracy: 0.7027
# Epoch 162/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8561 - accuracy: 0.6602 - val_loss: 0.8070 - val_accuracy: 0.7087
# Epoch 163/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8448 - accuracy: 0.6648 - val_loss: 0.8148 - val_accuracy: 0.7073
# Epoch 164/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.8338 - accuracy: 0.6731 - val_loss: 0.8097 - val_accuracy: 0.6973
# Epoch 165/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8391 - accuracy: 0.6654 - val_loss: 0.8044 - val_accuracy: 0.7160
# Epoch 166/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8456 - accuracy: 0.6645 - val_loss: 0.8073 - val_accuracy: 0.7053
# Epoch 167/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8523 - accuracy: 0.6629 - val_loss: 0.7884 - val_accuracy: 0.7187
# Epoch 168/300
# 215/218 [============================>.] - ETA: 0s - loss: 0.8462 - accuracy: 0.6667
# val accuracy high enough and difference between train and test is greater than 73.00%, so stopping training!!
# 218/218 [==============================] - 3s 15ms/step - loss: 0.8446 - accuracy: 0.6672 - val_loss: 0.7846 - val_accuracy: 0.7313

# %% [markdown]
# ## (vi)(CNN-Attention) Visualizing the accuracy and loss trajectory

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['accuracy'])
plt.plot(hybrid_cnn_lstm_model_results.history['val_accuracy'])
plt.title('CNN-Self_attention model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_lstm_model_results.history['val_loss'],'o')
plt.title('CNN-Self_attention model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## (vii)(CNN-LSTM) Testing the performance of the hybrid CNN-LSTM model on the held out test set

# %%
## Testing the hybrid CNN-LSTM model

hybrid_cnn_lstm_score = hybrid_cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hybrid CNN-attention model:',hybrid_cnn_lstm_score[1])
# Out:
# Test accuracy of the hybrid CNN-attention model: 0.6805869340896606
