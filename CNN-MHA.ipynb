# %% [markdown]
# ## CNN-MHA

# %% [markdown]
# #### This notebook was inspired to Tonmoy with some attempts to tune by us

# %% [markdown]
# ## (i) Importing the necessary packages

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
from keras import layers
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Flatten,Dropout,Bidirectional, GlobalAveragePooling2D
from keras.layers import Conv2D, LayerNormalization, LSTM,BatchNormalization,MaxPooling2D,Reshape, Lambda, MultiHeadAttention
from keras.utils import to_categorical
import matplotlib.pyplot as plt

tf.compat.v1.random.set_random_seed(0)

# %% [markdown]
# ## (ii) Preprocessing the dataset and preparing the training, validation, and test datasets

# %%
def data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,500)
    X = X[:,:,0:500]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape)
    return total_X,total_y

# %%
## Loading the dataset


X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769


## Random splitting and reshaping the data
# First generating the training and validation indices using random splitting

ind_valid = np.random.choice(2115, 375, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(X_train, X_valid) = X_train_valid[ind_train], X_train_valid[ind_valid] 
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]


## Preprocessing the dataset
x_train,y_train = data_prep(X_train,y_train,2,2,True)
x_valid,y_valid = data_prep(X_valid,y_valid,2,2,True)
X_test_prep,y_test_prep = data_prep(X_test,y_test,2,2,True)


print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)
print('Shape of testing set:',X_test_prep.shape)
print('Shape of testing labels:',y_test_prep.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test_prep, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)

keras.backend.clear_session()
# Out:
# Shape of X after trimming: (1740, 22, 500)
# Shape of X after maxpooling: (1740, 22, 250)
# Shape of X after averaging+noise and concatenating: (3480, 22, 250)
# Shape of X after subsampling and concatenating: (6960, 22, 250)
# Shape of X after trimming: (375, 22, 500)
# Shape of X after maxpooling: (375, 22, 250)
# Shape of X after averaging+noise and concatenating: (750, 22, 250)
# Shape of X after subsampling and concatenating: (1500, 22, 250)
# Shape of X after trimming: (443, 22, 500)
# Shape of X after maxpooling: (443, 22, 250)
# Shape of X after averaging+noise and concatenating: (886, 22, 250)
# Shape of X after subsampling and concatenating: (1772, 22, 250)
# Shape of training set: (6960, 22, 250)
# Shape of validation set: (1500, 22, 250)
# Shape of training labels: (6960,)
# Shape of validation labels: (1500,)
# Shape of testing set: (1772, 22, 250)
# Shape of testing labels: (1772,)
# Shape of training labels after categorical conversion: (6960, 4)
# Shape of validation labels after categorical conversion: (1500, 4)
# Shape of test labels after categorical conversion: (1772, 4)
# Shape of training set after adding width info: (6960, 22, 250, 1)
# Shape of validation set after adding width info: (1500, 22, 250, 1)
# Shape of test set after adding width info: (1772, 22, 250, 1)
# Shape of training set after dimension reshaping: (6960, 250, 1, 22)
# Shape of validation set after dimension reshaping: (1500, 250, 1, 22)
# Shape of test set after dimension reshaping: (1772, 250, 1, 22)

# %% [markdown]
# ## (iii)(CNN-LSTM) Defining the architecture of the hybrid CNN-LSTM model

# %%
# Building the CNN model using functional class
def build_model():
# models = []

    n_frames = 250
    n_channels = 22
    # Conv. block 1
    In1 = keras.Input(shape =(250,1,22) )
    c1 = Conv2D(filters=30, kernel_size=(11,1), padding='same', activation='swish')(In1)
    p1 =  MaxPooling2D(pool_size=(4,1), padding='same')(c1) # Read the keras documentation
    b1 = BatchNormalization()(p1)
    d1 = Dropout(0.8)(b1)

    # Conv. block 2
    c2 = Conv2D(filters=60, kernel_size=(9,1), padding='same', activation='swish')(d1)
    p2 =  MaxPooling2D(pool_size=(4,1), padding='same')(c2) # Read the keras documentation
    b2 = BatchNormalization()(p2)
    d2 = Dropout(0.7)(b2)

    # Conv. block 3
    c3 = Conv2D(filters=120, kernel_size=(5,1), padding='same', activation='gelu')(d2)
    p3 =  MaxPooling2D(pool_size=(4,1), padding='same')(c3) # Read the keras documentation
    b3 = BatchNormalization()(p3)
    d3 = Dropout(0.6)(b3)

    # Conv. block 4
    c4 = Conv2D(filters=240, kernel_size=(3,1), padding='same', activation='gelu')(d3)
    p4 =  MaxPooling2D(pool_size=(4,1), padding='same')(c4) # Read the keras documentation
    b4 = BatchNormalization()(p4)
    d4 = Dropout(0.5)(b4)

    
    #attention
    query_inputs = d4
    key_inputs = d4
    value_inputs = d4

    multi_head_attention = MultiHeadAttention(num_heads=8, key_dim=n_channels // 8)(query_inputs, key_inputs, value_inputs)
    multi_head_attention = LayerNormalization(epsilon=1e-6)(multi_head_attention)
    multi_head_attention = GlobalAveragePooling2D()(multi_head_attention)

    # Add fully connected layers
    fc1 = Dense(64, activation='relu')(multi_head_attention)
    fc1_dropout = Dropout(rate=0.5)(fc1)
    fc2 = Dense(4, activation='softmax')(fc1_dropout)

    # Define the final model
    final_model = Model(inputs=In1, outputs=[fc2])

    # # Printing the model summary
    final_model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])
    final_model.summary()
    return final_model

# %% [markdown]
# ## (iv)(CNN-LSTM) Defining the hyperparameters of the hybrid CNN-LSTM model

# %%
# Model parameters
epochs = 300
initial_learning_rate = 1e-3
decay_steps = 1000
decay_rate = 0.99

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=decay_steps,
    decay_rate=decay_rate
)

optimizer = keras.optimizers.Adam(learning_rate=lr_schedule)

# %% [markdown]
# ## (v)Attention at the end

# %%
# Compiling the model
keras.backend.clear_session()

# Training and validating the model

batch_sizes = [32,64,128]
import matplotlib.pyplot as plt

hybrid_cnn_lstm_model = build_model()
# Compiling the model
hybrid_cnn_lstm_model.compile(loss='categorical_crossentropy',
               optimizer=optimizer,
               metrics=['accuracy'])

# Training and validating the model
acc = 0.73
class myCallback(tf.keras.callbacks.Callback):
	def on_epoch_end(self, epoch, logs={}):
		if(logs.get('val_accuracy') > acc):
			print("\nval accuracy high enough and is greater than %2.2f%%, so stopping training!!" %(acc*100))
			self.model.stop_training = True

# Instantiate a callback object
callback = myCallback()
# callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
hybrid_cnn_lstm_model_results = hybrid_cnn_lstm_model.fit(x_train,
                y_train,
                batch_size=32,
                epochs=epochs,
                validation_data=(x_valid, y_valid), 
                verbose=True,
                callbacks = [callback]
                )
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 250, 1, 22)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 250, 1, 30)   7290        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 63, 1, 30)    0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 63, 1, 30)   120         ['max_pooling2d[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 63, 1, 30)    0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 63, 1, 60)    16260       ['dropout[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 1, 60)   0           ['conv2d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 1, 60)   240         ['max_pooling2d_1[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 16, 1, 60)    0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 1, 120)   36120       ['dropout_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 4, 1, 120)   0           ['conv2d_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 4, 1, 120)   480         ['max_pooling2d_2[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 4, 1, 120)    0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 4, 1, 240)    86640       ['dropout_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 1, 1, 240)   0           ['conv2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 1, 1, 240)   960         ['max_pooling2d_3[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 1, 1, 240)    0           ['batch_normalization_3[0][0]']
#
#  multi_head_attention (MultiHea  (None, 1, 1, 240)   15648       ['dropout_3[0][0]',
#  dAttention)                                                      'dropout_3[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  layer_normalization (LayerNorm  (None, 1, 1, 240)   480         ['multi_head_attention[0][0]']
#  alization)
#
#  global_average_pooling2d (Glob  (None, 240)         0           ['layer_normalization[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 64)           15424       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout_4 (Dropout)            (None, 64)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 4)            260         ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 179,922
# Trainable params: 179,022
# Non-trainable params: 900
# __________________________________________________________________________________________________
# Epoch 1/300
# 218/218 [==============================] - 5s 16ms/step - loss: 1.5273 - accuracy: 0.2481 - val_loss: 1.3959 - val_accuracy: 0.2667
# Epoch 2/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.3932 - accuracy: 0.2575 - val_loss: 1.3890 - val_accuracy: 0.2267
# Epoch 3/300
# 218/218 [==============================] - 4s 18ms/step - loss: 1.3874 - accuracy: 0.2672 - val_loss: 1.4044 - val_accuracy: 0.2267
# Epoch 4/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.3900 - accuracy: 0.2670 - val_loss: 1.3885 - val_accuracy: 0.2327
# Epoch 5/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3883 - accuracy: 0.2583 - val_loss: 1.3873 - val_accuracy: 0.2427
# Epoch 6/300
# 218/218 [==============================] - 4s 18ms/step - loss: 1.3856 - accuracy: 0.2638 - val_loss: 1.3913 - val_accuracy: 0.2267
# Epoch 7/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3858 - accuracy: 0.2655 - val_loss: 1.3885 - val_accuracy: 0.2667
# Epoch 8/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3855 - accuracy: 0.2634 - val_loss: 1.3902 - val_accuracy: 0.2667
# Epoch 9/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3867 - accuracy: 0.2589 - val_loss: 1.3944 - val_accuracy: 0.2267
# Epoch 10/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3855 - accuracy: 0.2641 - val_loss: 1.3874 - val_accuracy: 0.2627
# Epoch 11/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3828 - accuracy: 0.2697 - val_loss: 1.3853 - val_accuracy: 0.2633
# Epoch 12/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3836 - accuracy: 0.2685 - val_loss: 1.3847 - val_accuracy: 0.2533
# Epoch 13/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3832 - accuracy: 0.2671 - val_loss: 1.3963 - val_accuracy: 0.2667
# Epoch 14/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3811 - accuracy: 0.2680 - val_loss: 1.3835 - val_accuracy: 0.2680
# Epoch 15/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3744 - accuracy: 0.2694 - val_loss: 1.4097 - val_accuracy: 0.2707
# Epoch 16/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3757 - accuracy: 0.2800 - val_loss: 1.3822 - val_accuracy: 0.2707
# Epoch 17/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3723 - accuracy: 0.2773 - val_loss: 1.3784 - val_accuracy: 0.2620
# Epoch 18/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3622 - accuracy: 0.2948 - val_loss: 1.3607 - val_accuracy: 0.3060
# Epoch 19/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3596 - accuracy: 0.3072 - val_loss: 1.3510 - val_accuracy: 0.3033
# Epoch 20/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3442 - accuracy: 0.3205 - val_loss: 1.3597 - val_accuracy: 0.2887
# Epoch 21/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3343 - accuracy: 0.3325 - val_loss: 1.3460 - val_accuracy: 0.3327
# Epoch 22/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3305 - accuracy: 0.3517 - val_loss: 1.3082 - val_accuracy: 0.3627
# Epoch 23/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3178 - accuracy: 0.3619 - val_loss: 1.3229 - val_accuracy: 0.3340
# Epoch 24/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3194 - accuracy: 0.3599 - val_loss: 1.3169 - val_accuracy: 0.3420
# Epoch 25/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.3071 - accuracy: 0.3806 - val_loss: 1.2758 - val_accuracy: 0.4073
# Epoch 26/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.2951 - accuracy: 0.3878 - val_loss: 1.2799 - val_accuracy: 0.3840
# Epoch 27/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2979 - accuracy: 0.3812 - val_loss: 1.2727 - val_accuracy: 0.4173
# Epoch 28/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2923 - accuracy: 0.4037 - val_loss: 1.2930 - val_accuracy: 0.3453
# Epoch 29/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.2943 - accuracy: 0.3920 - val_loss: 1.2631 - val_accuracy: 0.4260
# Epoch 30/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2889 - accuracy: 0.3981 - val_loss: 1.2976 - val_accuracy: 0.3540
# Epoch 31/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.2849 - accuracy: 0.3944 - val_loss: 1.2887 - val_accuracy: 0.3400
# Epoch 32/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2724 - accuracy: 0.4116 - val_loss: 1.2710 - val_accuracy: 0.3647
# Epoch 33/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2666 - accuracy: 0.4188 - val_loss: 1.2355 - val_accuracy: 0.4107
# Epoch 34/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2617 - accuracy: 0.4239 - val_loss: 1.2751 - val_accuracy: 0.3633
# Epoch 35/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2568 - accuracy: 0.4190 - val_loss: 1.2693 - val_accuracy: 0.3667
# Epoch 36/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2525 - accuracy: 0.4329 - val_loss: 1.2875 - val_accuracy: 0.3413
# Epoch 37/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2550 - accuracy: 0.4312 - val_loss: 1.2807 - val_accuracy: 0.3540
# Epoch 38/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2421 - accuracy: 0.4349 - val_loss: 1.2054 - val_accuracy: 0.4167
# Epoch 39/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2410 - accuracy: 0.4338 - val_loss: 1.2150 - val_accuracy: 0.4000
# Epoch 40/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2372 - accuracy: 0.4425 - val_loss: 1.2334 - val_accuracy: 0.3820
# Epoch 41/300
# 218/218 [==============================] - 4s 17ms/step - loss: 1.2264 - accuracy: 0.4412 - val_loss: 1.2393 - val_accuracy: 0.3807
# Epoch 42/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.2396 - accuracy: 0.4412 - val_loss: 1.2411 - val_accuracy: 0.3867
# Epoch 43/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.2234 - accuracy: 0.4422 - val_loss: 1.2482 - val_accuracy: 0.3687
# Epoch 44/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.2268 - accuracy: 0.4379 - val_loss: 1.2189 - val_accuracy: 0.3927
# Epoch 45/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2140 - accuracy: 0.4451 - val_loss: 1.2369 - val_accuracy: 0.3893
# Epoch 46/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2158 - accuracy: 0.4566 - val_loss: 1.2491 - val_accuracy: 0.3707
# Epoch 47/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.2119 - accuracy: 0.4481 - val_loss: 1.2165 - val_accuracy: 0.4100
# Epoch 48/300
# 218/218 [==============================] - 4s 16ms/step - loss: 1.2109 - accuracy: 0.4533 - val_loss: 1.1924 - val_accuracy: 0.4187
# Epoch 49/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.2030 - accuracy: 0.4583 - val_loss: 1.2326 - val_accuracy: 0.3867
# Epoch 50/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1992 - accuracy: 0.4552 - val_loss: 1.2289 - val_accuracy: 0.3920
# Epoch 51/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1925 - accuracy: 0.4655 - val_loss: 1.2048 - val_accuracy: 0.3927
# Epoch 52/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2002 - accuracy: 0.4545 - val_loss: 1.1907 - val_accuracy: 0.4133
# Epoch 53/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1968 - accuracy: 0.4565 - val_loss: 1.2110 - val_accuracy: 0.3753
# Epoch 54/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1836 - accuracy: 0.4608 - val_loss: 1.1940 - val_accuracy: 0.4147
# Epoch 55/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1802 - accuracy: 0.4647 - val_loss: 1.1848 - val_accuracy: 0.4187
# Epoch 56/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1916 - accuracy: 0.4573 - val_loss: 1.2068 - val_accuracy: 0.4007
# Epoch 57/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1656 - accuracy: 0.4779 - val_loss: 1.1907 - val_accuracy: 0.4173
# Epoch 58/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1767 - accuracy: 0.4668 - val_loss: 1.1685 - val_accuracy: 0.4340
# Epoch 59/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1831 - accuracy: 0.4671 - val_loss: 1.2006 - val_accuracy: 0.3987
# Epoch 60/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1683 - accuracy: 0.4711 - val_loss: 1.1838 - val_accuracy: 0.4293
# Epoch 61/300
# 218/218 [==============================] - 4s 17ms/step - loss: 1.1658 - accuracy: 0.4815 - val_loss: 1.2152 - val_accuracy: 0.3987
# Epoch 62/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1725 - accuracy: 0.4691 - val_loss: 1.1936 - val_accuracy: 0.4113
# Epoch 63/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1607 - accuracy: 0.4760 - val_loss: 1.2096 - val_accuracy: 0.4140
# Epoch 64/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1560 - accuracy: 0.4710 - val_loss: 1.1526 - val_accuracy: 0.4620
# Epoch 65/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1442 - accuracy: 0.4800 - val_loss: 1.1541 - val_accuracy: 0.4493
# Epoch 66/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1519 - accuracy: 0.4799 - val_loss: 1.1735 - val_accuracy: 0.4460
# Epoch 67/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1461 - accuracy: 0.4871 - val_loss: 1.1579 - val_accuracy: 0.4440
# Epoch 68/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1366 - accuracy: 0.4912 - val_loss: 1.1567 - val_accuracy: 0.4560
# Epoch 69/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1442 - accuracy: 0.4856 - val_loss: 1.1328 - val_accuracy: 0.4927
# Epoch 70/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1425 - accuracy: 0.4855 - val_loss: 1.1859 - val_accuracy: 0.4500
# Epoch 71/300
# 218/218 [==============================] - 4s 17ms/step - loss: 1.1321 - accuracy: 0.4951 - val_loss: 1.1461 - val_accuracy: 0.4567
# Epoch 72/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1412 - accuracy: 0.4902 - val_loss: 1.1651 - val_accuracy: 0.4413
# Epoch 73/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1386 - accuracy: 0.4826 - val_loss: 1.1602 - val_accuracy: 0.4307
# Epoch 74/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1377 - accuracy: 0.4826 - val_loss: 1.1669 - val_accuracy: 0.4327
# Epoch 75/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1320 - accuracy: 0.4889 - val_loss: 1.1298 - val_accuracy: 0.4507
# Epoch 76/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1286 - accuracy: 0.4994 - val_loss: 1.1426 - val_accuracy: 0.4700
# Epoch 77/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1202 - accuracy: 0.5045 - val_loss: 1.1776 - val_accuracy: 0.4273
# Epoch 78/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1307 - accuracy: 0.4908 - val_loss: 1.1420 - val_accuracy: 0.4580
# Epoch 79/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1245 - accuracy: 0.4836 - val_loss: 1.1446 - val_accuracy: 0.4540
# Epoch 80/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1203 - accuracy: 0.4976 - val_loss: 1.1634 - val_accuracy: 0.4373
# Epoch 81/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1058 - accuracy: 0.5011 - val_loss: 1.1626 - val_accuracy: 0.4433
# Epoch 82/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1071 - accuracy: 0.4960 - val_loss: 1.1311 - val_accuracy: 0.4633
# Epoch 83/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1038 - accuracy: 0.5050 - val_loss: 1.1389 - val_accuracy: 0.4573
# Epoch 84/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1156 - accuracy: 0.5020 - val_loss: 1.1227 - val_accuracy: 0.4553
# Epoch 85/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1002 - accuracy: 0.5075 - val_loss: 1.1441 - val_accuracy: 0.4433
# Epoch 86/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0997 - accuracy: 0.5128 - val_loss: 1.1237 - val_accuracy: 0.4687
# Epoch 87/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1125 - accuracy: 0.5024 - val_loss: 1.1139 - val_accuracy: 0.4807
# Epoch 88/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1082 - accuracy: 0.4981 - val_loss: 1.1355 - val_accuracy: 0.4520
# Epoch 89/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1001 - accuracy: 0.5060 - val_loss: 1.1247 - val_accuracy: 0.4793
# Epoch 90/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1035 - accuracy: 0.5009 - val_loss: 1.1103 - val_accuracy: 0.4840
# Epoch 91/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0997 - accuracy: 0.5124 - val_loss: 1.1304 - val_accuracy: 0.4587
# Epoch 92/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0932 - accuracy: 0.5148 - val_loss: 1.0898 - val_accuracy: 0.5007
# Epoch 93/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.0907 - accuracy: 0.5148 - val_loss: 1.1246 - val_accuracy: 0.4560
# Epoch 94/300
# 218/218 [==============================] - 4s 17ms/step - loss: 1.0938 - accuracy: 0.5165 - val_loss: 1.1234 - val_accuracy: 0.4593
# Epoch 95/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.0763 - accuracy: 0.5253 - val_loss: 1.1055 - val_accuracy: 0.4820
# Epoch 96/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.0786 - accuracy: 0.5188 - val_loss: 1.1090 - val_accuracy: 0.4800
# Epoch 97/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.0774 - accuracy: 0.5322 - val_loss: 1.1178 - val_accuracy: 0.4867
# Epoch 98/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.0839 - accuracy: 0.5188 - val_loss: 1.1071 - val_accuracy: 0.4933
# Epoch 99/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0802 - accuracy: 0.5204 - val_loss: 1.1119 - val_accuracy: 0.4627
# Epoch 100/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0685 - accuracy: 0.5282 - val_loss: 1.1132 - val_accuracy: 0.4780
# Epoch 101/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0745 - accuracy: 0.5353 - val_loss: 1.1382 - val_accuracy: 0.4573
# Epoch 102/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0733 - accuracy: 0.5250 - val_loss: 1.1161 - val_accuracy: 0.4667
# Epoch 103/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0752 - accuracy: 0.5303 - val_loss: 1.0780 - val_accuracy: 0.4793
# Epoch 104/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0821 - accuracy: 0.5364 - val_loss: 1.1246 - val_accuracy: 0.4627
# Epoch 105/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0709 - accuracy: 0.5358 - val_loss: 1.1052 - val_accuracy: 0.5047
# Epoch 106/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0683 - accuracy: 0.5335 - val_loss: 1.0934 - val_accuracy: 0.5080
# Epoch 107/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0475 - accuracy: 0.5493 - val_loss: 1.1305 - val_accuracy: 0.4840
# Epoch 108/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0620 - accuracy: 0.5438 - val_loss: 1.0779 - val_accuracy: 0.5153
# Epoch 109/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0564 - accuracy: 0.5506 - val_loss: 1.0861 - val_accuracy: 0.5067
# Epoch 110/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0551 - accuracy: 0.5573 - val_loss: 1.0669 - val_accuracy: 0.5387
# Epoch 111/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.0390 - accuracy: 0.5659 - val_loss: 1.0706 - val_accuracy: 0.5527
# Epoch 112/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0482 - accuracy: 0.5467 - val_loss: 1.0784 - val_accuracy: 0.5247
# Epoch 113/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0466 - accuracy: 0.5576 - val_loss: 1.0605 - val_accuracy: 0.5327
# Epoch 114/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0535 - accuracy: 0.5675 - val_loss: 1.0874 - val_accuracy: 0.5140
# Epoch 115/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0452 - accuracy: 0.5572 - val_loss: 1.0679 - val_accuracy: 0.5433
# Epoch 116/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0386 - accuracy: 0.5743 - val_loss: 1.0787 - val_accuracy: 0.5067
# Epoch 117/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.0181 - accuracy: 0.5797 - val_loss: 1.0824 - val_accuracy: 0.5313
# Epoch 118/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0277 - accuracy: 0.5779 - val_loss: 1.0464 - val_accuracy: 0.5600
# Epoch 119/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.0153 - accuracy: 0.5849 - val_loss: 1.0287 - val_accuracy: 0.5607
# Epoch 120/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.0272 - accuracy: 0.5751 - val_loss: 1.0339 - val_accuracy: 0.5627
# Epoch 121/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0265 - accuracy: 0.5723 - val_loss: 1.0476 - val_accuracy: 0.5513
# Epoch 122/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0240 - accuracy: 0.5740 - val_loss: 1.0341 - val_accuracy: 0.5553
# Epoch 123/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0135 - accuracy: 0.5767 - val_loss: 1.0459 - val_accuracy: 0.5440
# Epoch 124/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0100 - accuracy: 0.5876 - val_loss: 1.0329 - val_accuracy: 0.5627
# Epoch 125/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9985 - accuracy: 0.5852 - val_loss: 1.0220 - val_accuracy: 0.5547
# Epoch 126/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0024 - accuracy: 0.5862 - val_loss: 1.0267 - val_accuracy: 0.5647
# Epoch 127/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0108 - accuracy: 0.5930 - val_loss: 1.0307 - val_accuracy: 0.5747
# Epoch 128/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0061 - accuracy: 0.5899 - val_loss: 1.0141 - val_accuracy: 0.5667
# Epoch 129/300
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0110 - accuracy: 0.5853 - val_loss: 1.0224 - val_accuracy: 0.5693
# Epoch 130/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9962 - accuracy: 0.5924 - val_loss: 1.0450 - val_accuracy: 0.5493
# Epoch 131/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.0165 - accuracy: 0.5920 - val_loss: 1.0180 - val_accuracy: 0.5593
# Epoch 132/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9970 - accuracy: 0.5986 - val_loss: 1.0455 - val_accuracy: 0.5447
# Epoch 133/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9990 - accuracy: 0.5920 - val_loss: 1.0274 - val_accuracy: 0.5593
# Epoch 134/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9936 - accuracy: 0.6045 - val_loss: 1.0109 - val_accuracy: 0.5673
# Epoch 135/300
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9847 - accuracy: 0.6057 - val_loss: 1.0355 - val_accuracy: 0.5627
# Epoch 136/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9847 - accuracy: 0.5994 - val_loss: 1.0043 - val_accuracy: 0.5933
# Epoch 137/300
# 218/218 [==============================] - 4s 17ms/step - loss: 0.9902 - accuracy: 0.5921 - val_loss: 1.0138 - val_accuracy: 0.5667
# Epoch 138/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9872 - accuracy: 0.5984 - val_loss: 1.0004 - val_accuracy: 0.5740
# Epoch 139/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9908 - accuracy: 0.6034 - val_loss: 1.0095 - val_accuracy: 0.5560
# Epoch 140/300
#   1/218 [..............................] - ETA: 2s - loss: 0.9552 - accuracy: 0.6562

# %% [markdown]
# ## (vi)(CNN-Attention) Visualizing the accuracy and loss trajectory

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['accuracy'])
plt.plot(hybrid_cnn_lstm_model_results.history['val_accuracy'])
plt.title('CNN-MHA model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_lstm_model_results.history['val_loss'],'o')
plt.title('CNN-MHA model model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## (vii)(CNN-LSTM) Testing the performance of the hybrid CNN-LSTM model on the held out test set

# %%
## Testing the hybrid CNN-LSTM model

hybrid_cnn_lstm_score = hybrid_cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hybrid CNN-MHA model:',hybrid_cnn_lstm_score[1])
# Out:
# Test accuracy of the hybrid CNN-MHA model: 0.678329586982727
