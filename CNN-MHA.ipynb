# %% [markdown]
# ## CNN-MHA

# %% [markdown]
# #### This notebook was inspired to Tonmoy with some attempts to tune by us

# %% [markdown]
# ## (i) Importing the necessary packages

# %%
import numpy as np
import pandas as pd
import keras
from keras import layers
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Flatten,Dropout,Bidirectional, GlobalAveragePooling2D
from keras.layers import Conv2D, LayerNormalization, LSTM,BatchNormalization,MaxPooling2D,Reshape, Lambda, MultiHeadAttention
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %% [markdown]
# ## (ii) Preprocessing the dataset and preparing the training, validation, and test datasets

# %%
def data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,500)
    X = X[:,:,0:500]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape)
    return total_X,total_y

# %%
## Loading the dataset


X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769


## Random splitting and reshaping the data
# First generating the training and validation indices using random splitting

ind_valid = np.random.choice(2115, 375, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(X_train, X_valid) = X_train_valid[ind_train], X_train_valid[ind_valid] 
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]


## Preprocessing the dataset
x_train,y_train = data_prep(X_train,y_train,2,2,True)
x_valid,y_valid = data_prep(X_valid,y_valid,2,2,True)
X_test_prep,y_test_prep = data_prep(X_test,y_test,2,2,True)


print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)
print('Shape of testing set:',X_test_prep.shape)
print('Shape of testing labels:',y_test_prep.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test_prep, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)

keras.backend.clear_session()
# Out:
# Shape of X after trimming: (1740, 22, 500)
# Shape of X after maxpooling: (1740, 22, 250)
# Shape of X after averaging+noise and concatenating: (3480, 22, 250)
# Shape of X after subsampling and concatenating: (6960, 22, 250)
# Shape of X after trimming: (375, 22, 500)
# Shape of X after maxpooling: (375, 22, 250)
# Shape of X after averaging+noise and concatenating: (750, 22, 250)
# Shape of X after subsampling and concatenating: (1500, 22, 250)
# Shape of X after trimming: (443, 22, 500)
# Shape of X after maxpooling: (443, 22, 250)
# Shape of X after averaging+noise and concatenating: (886, 22, 250)
# Shape of X after subsampling and concatenating: (1772, 22, 250)
# Shape of training set: (6960, 22, 250)
# Shape of validation set: (1500, 22, 250)
# Shape of training labels: (6960,)
# Shape of validation labels: (1500,)
# Shape of testing set: (1772, 22, 250)
# Shape of testing labels: (1772,)
# Shape of training labels after categorical conversion: (6960, 4)
# Shape of validation labels after categorical conversion: (1500, 4)
# Shape of test labels after categorical conversion: (1772, 4)
# Shape of training set after adding width info: (6960, 22, 250, 1)
# Shape of validation set after adding width info: (1500, 22, 250, 1)
# Shape of test set after adding width info: (1772, 22, 250, 1)
# Shape of training set after dimension reshaping: (6960, 250, 1, 22)
# Shape of validation set after dimension reshaping: (1500, 250, 1, 22)
# Shape of test set after dimension reshaping: (1772, 250, 1, 22)

# %% [markdown]
# ## (iii)(CNN-LSTM) Defining the architecture of the hybrid CNN-LSTM model

# %%
# Building the CNN model using functional class
def build_model():
# models = []

    n_frames = 250
    n_channels = 22
    # Conv. block 1
    In1 = keras.Input(shape =(250,1,22) )
    c1 = Conv2D(filters=30, kernel_size=(11,1), padding='same', activation='swish')(In1)
    p1 =  MaxPooling2D(pool_size=(4,1), padding='same')(c1) # Read the keras documentation
    b1 = BatchNormalization()(p1)
    d1 = Dropout(0.8)(b1)

    # Conv. block 2
    c2 = Conv2D(filters=60, kernel_size=(9,1), padding='same', activation='swish')(d1)
    p2 =  MaxPooling2D(pool_size=(4,1), padding='same')(c2) # Read the keras documentation
    b2 = BatchNormalization()(p2)
    d2 = Dropout(0.7)(b2)

    # Conv. block 3
    c3 = Conv2D(filters=120, kernel_size=(5,1), padding='same', activation='gelu')(d2)
    p3 =  MaxPooling2D(pool_size=(4,1), padding='same')(c3) # Read the keras documentation
    b3 = BatchNormalization()(p3)
    d3 = Dropout(0.6)(b3)

    # Conv. block 4
    c4 = Conv2D(filters=240, kernel_size=(3,1), padding='same', activation='gelu')(d3)
    p4 =  MaxPooling2D(pool_size=(4,1), padding='same')(c4) # Read the keras documentation
    b4 = BatchNormalization()(p4)
    d4 = Dropout(0.5)(b4)

    
    #attention
    query_inputs = d4
    key_inputs = d4
    value_inputs = d4

    multi_head_attention = MultiHeadAttention(num_heads=8, key_dim=n_channels // 8)(query_inputs, key_inputs, value_inputs)
    multi_head_attention = LayerNormalization(epsilon=1e-6)(multi_head_attention)
    multi_head_attention = GlobalAveragePooling2D()(multi_head_attention)

    # Add fully connected layers
    fc1 = Dense(64, activation='relu')(multi_head_attention)
    fc1_dropout = Dropout(rate=0.5)(fc1)
    fc2 = Dense(4, activation='softmax')(fc1_dropout)

    # Define the final model
    final_model = Model(inputs=In1, outputs=[fc2])

    # # Printing the model summary
    final_model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])
    final_model.summary()
    return final_model

# %% [markdown]
# ## (iv)(CNN-LSTM) Defining the hyperparameters of the hybrid CNN-LSTM model

# %%
import tensorflow as tf
# Model parameters
epochs = 300
initial_learning_rate = 1e-3
decay_steps = 1000
decay_rate = 0.99

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=decay_steps,
    decay_rate=decay_rate
)

optimizer = keras.optimizers.Adam(learning_rate=lr_schedule)

# %% [markdown]
# ## (v)Attention at the end

# %%
# Compiling the model
keras.backend.clear_session()

# Training and validating the model

batch_sizes = [32,64,128]
import matplotlib.pyplot as plt

hybrid_cnn_lstm_model = build_model()
# Compiling the model
hybrid_cnn_lstm_model.compile(loss='categorical_crossentropy',
               optimizer=optimizer,
               metrics=['accuracy'])

# Training and validating the model
acc = 0.73
class myCallback(tf.keras.callbacks.Callback):
	def on_epoch_end(self, epoch, logs={}):
		if(logs.get('val_accuracy') > acc):
			print("\nval accuracy high enough and is greater than %2.2f%%, so stopping training!!" %(acc*100))
			self.model.stop_training = True

# Instantiate a callback object
callback = myCallback()
# callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
hybrid_cnn_lstm_model_results = hybrid_cnn_lstm_model.fit(x_train,
                y_train,
                batch_size=32,
                epochs=epochs,
                validation_data=(x_valid, y_valid), 
                verbose=True,
                callbacks = [callback]
                )
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 250, 1, 22)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 250, 1, 30)   7290        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 63, 1, 30)    0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 63, 1, 30)   120         ['max_pooling2d[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 63, 1, 30)    0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 63, 1, 60)    16260       ['dropout[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 1, 60)   0           ['conv2d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 1, 60)   240         ['max_pooling2d_1[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 16, 1, 60)    0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 1, 120)   36120       ['dropout_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 4, 1, 120)   0           ['conv2d_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 4, 1, 120)   480         ['max_pooling2d_2[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 4, 1, 120)    0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 4, 1, 240)    86640       ['dropout_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 1, 1, 240)   0           ['conv2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 1, 1, 240)   960         ['max_pooling2d_3[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 1, 1, 240)    0           ['batch_normalization_3[0][0]']
#
#  multi_head_attention (MultiHea  (None, 1, 1, 240)   15648       ['dropout_3[0][0]',
#  dAttention)                                                      'dropout_3[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  layer_normalization (LayerNorm  (None, 1, 1, 240)   480         ['multi_head_attention[0][0]']
#  alization)
#
#  global_average_pooling2d (Glob  (None, 240)         0           ['layer_normalization[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 64)           15424       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout_4 (Dropout)            (None, 64)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 4)            260         ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 179,922
# Trainable params: 179,022
# Non-trainable params: 900
# __________________________________________________________________________________________________
# Epoch 1/300
# 218/218 [==============================] - 6s 21ms/step - loss: 1.5071 - accuracy: 0.2534 - val_loss: 1.3851 - val_accuracy: 0.2473
# Epoch 2/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.3926 - accuracy: 0.2618 - val_loss: 1.3884 - val_accuracy: 0.1993
# Epoch 3/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.3859 - accuracy: 0.2697 - val_loss: 1.3894 - val_accuracy: 0.2053
# Epoch 4/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.3847 - accuracy: 0.2685 - val_loss: 1.3881 - val_accuracy: 0.3067
# Epoch 5/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.3837 - accuracy: 0.2707 - val_loss: 1.3912 - val_accuracy: 0.2053
# Epoch 6/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.3829 - accuracy: 0.2733 - val_loss: 1.3916 - val_accuracy: 0.2053
# Epoch 7/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.3822 - accuracy: 0.2760 - val_loss: 1.3919 - val_accuracy: 0.2053
# Epoch 8/300
# 218/218 [==============================] - 5s 23ms/step - loss: 1.3832 - accuracy: 0.2789 - val_loss: 1.3827 - val_accuracy: 0.2560
# Epoch 9/300
# 218/218 [==============================] - 5s 24ms/step - loss: 1.3786 - accuracy: 0.2898 - val_loss: 1.3934 - val_accuracy: 0.2053
# Epoch 10/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.3759 - accuracy: 0.2885 - val_loss: 1.3910 - val_accuracy: 0.2147
# Epoch 11/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.3690 - accuracy: 0.2996 - val_loss: 1.3859 - val_accuracy: 0.2367
# Epoch 12/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.3628 - accuracy: 0.3118 - val_loss: 1.3773 - val_accuracy: 0.2247
# Epoch 13/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.3581 - accuracy: 0.3106 - val_loss: 1.3719 - val_accuracy: 0.2567
# Epoch 14/300
# 218/218 [==============================] - 4s 19ms/step - loss: 1.3439 - accuracy: 0.3264 - val_loss: 1.3511 - val_accuracy: 0.2900
# Epoch 15/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.3409 - accuracy: 0.3379 - val_loss: 1.3261 - val_accuracy: 0.3347
# Epoch 16/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.3290 - accuracy: 0.3504 - val_loss: 1.3166 - val_accuracy: 0.3473
# Epoch 17/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.3181 - accuracy: 0.3599 - val_loss: 1.3094 - val_accuracy: 0.3573
# Epoch 18/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.3106 - accuracy: 0.3697 - val_loss: 1.3288 - val_accuracy: 0.3500
# Epoch 19/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.3088 - accuracy: 0.3777 - val_loss: 1.3126 - val_accuracy: 0.3527
# Epoch 20/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.3013 - accuracy: 0.3796 - val_loss: 1.3061 - val_accuracy: 0.3360
# Epoch 21/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.2887 - accuracy: 0.3981 - val_loss: 1.2911 - val_accuracy: 0.3693
# Epoch 22/300
# 218/218 [==============================] - 5s 23ms/step - loss: 1.2833 - accuracy: 0.4022 - val_loss: 1.3202 - val_accuracy: 0.3460
# Epoch 23/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.2774 - accuracy: 0.4030 - val_loss: 1.2749 - val_accuracy: 0.3567
# Epoch 24/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.2666 - accuracy: 0.4010 - val_loss: 1.2674 - val_accuracy: 0.3667
# Epoch 25/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.2634 - accuracy: 0.4109 - val_loss: 1.2753 - val_accuracy: 0.4100
# Epoch 26/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.2551 - accuracy: 0.4263 - val_loss: 1.2613 - val_accuracy: 0.3847
# Epoch 27/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.2511 - accuracy: 0.4237 - val_loss: 1.2518 - val_accuracy: 0.3787
# Epoch 28/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.2359 - accuracy: 0.4368 - val_loss: 1.2532 - val_accuracy: 0.3880
# Epoch 29/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.2433 - accuracy: 0.4333 - val_loss: 1.2671 - val_accuracy: 0.3653
# Epoch 30/300
# 218/218 [==============================] - 4s 16ms/step - loss: 1.2354 - accuracy: 0.4372 - val_loss: 1.2332 - val_accuracy: 0.3813
# Epoch 31/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.2314 - accuracy: 0.4428 - val_loss: 1.2269 - val_accuracy: 0.3780
# Epoch 32/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2157 - accuracy: 0.4500 - val_loss: 1.2131 - val_accuracy: 0.4173
# Epoch 33/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.2228 - accuracy: 0.4486 - val_loss: 1.2185 - val_accuracy: 0.3993
# Epoch 34/300
# 218/218 [==============================] - 4s 18ms/step - loss: 1.2202 - accuracy: 0.4527 - val_loss: 1.2444 - val_accuracy: 0.3660
# Epoch 35/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2145 - accuracy: 0.4536 - val_loss: 1.2270 - val_accuracy: 0.4040
# Epoch 36/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.2091 - accuracy: 0.4575 - val_loss: 1.2001 - val_accuracy: 0.4153
# Epoch 37/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1992 - accuracy: 0.4565 - val_loss: 1.2210 - val_accuracy: 0.4007
# Epoch 38/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1881 - accuracy: 0.4665 - val_loss: 1.2783 - val_accuracy: 0.3773
# Epoch 39/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1985 - accuracy: 0.4572 - val_loss: 1.2078 - val_accuracy: 0.4000
# Epoch 40/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1848 - accuracy: 0.4682 - val_loss: 1.2083 - val_accuracy: 0.4113
# Epoch 41/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1853 - accuracy: 0.4638 - val_loss: 1.2059 - val_accuracy: 0.4187
# Epoch 42/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1849 - accuracy: 0.4780 - val_loss: 1.2294 - val_accuracy: 0.3900
# Epoch 43/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1749 - accuracy: 0.4790 - val_loss: 1.1866 - val_accuracy: 0.4287
# Epoch 44/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1713 - accuracy: 0.4924 - val_loss: 1.1883 - val_accuracy: 0.4120
# Epoch 45/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1597 - accuracy: 0.4853 - val_loss: 1.1896 - val_accuracy: 0.4187
# Epoch 46/300
# 218/218 [==============================] - 4s 16ms/step - loss: 1.1679 - accuracy: 0.4806 - val_loss: 1.2320 - val_accuracy: 0.4220
# Epoch 47/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1660 - accuracy: 0.4955 - val_loss: 1.1985 - val_accuracy: 0.4280
# Epoch 48/300
# 218/218 [==============================] - 4s 16ms/step - loss: 1.1571 - accuracy: 0.4950 - val_loss: 1.1715 - val_accuracy: 0.4453
# Epoch 49/300
# 218/218 [==============================] - 4s 16ms/step - loss: 1.1526 - accuracy: 0.5000 - val_loss: 1.2107 - val_accuracy: 0.4260
# Epoch 50/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1386 - accuracy: 0.5116 - val_loss: 1.1990 - val_accuracy: 0.4333
# Epoch 51/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1370 - accuracy: 0.5050 - val_loss: 1.1787 - val_accuracy: 0.4367
# Epoch 52/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1283 - accuracy: 0.5089 - val_loss: 1.1701 - val_accuracy: 0.4753
# Epoch 53/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1328 - accuracy: 0.5085 - val_loss: 1.1471 - val_accuracy: 0.5093
# Epoch 54/300
# 218/218 [==============================] - 4s 16ms/step - loss: 1.1363 - accuracy: 0.5106 - val_loss: 1.1662 - val_accuracy: 0.4840
# Epoch 55/300
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1148 - accuracy: 0.5266 - val_loss: 1.1713 - val_accuracy: 0.4940
# Epoch 56/300
# 218/218 [==============================] - 4s 17ms/step - loss: 1.1170 - accuracy: 0.5187 - val_loss: 1.1699 - val_accuracy: 0.5253
# Epoch 57/300
# 218/218 [==============================] - 4s 17ms/step - loss: 1.1141 - accuracy: 0.5273 - val_loss: 1.1438 - val_accuracy: 0.5213
# Epoch 58/300
# 218/218 [==============================] - 4s 17ms/step - loss: 1.1080 - accuracy: 0.5299 - val_loss: 1.1495 - val_accuracy: 0.5127
# Epoch 59/300
# 218/218 [==============================] - 4s 16ms/step - loss: 1.1085 - accuracy: 0.5276 - val_loss: 1.1303 - val_accuracy: 0.5200
# Epoch 60/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.0905 - accuracy: 0.5392 - val_loss: 1.1403 - val_accuracy: 0.5227
# Epoch 61/300
# 218/218 [==============================] - 4s 16ms/step - loss: 1.0946 - accuracy: 0.5424 - val_loss: 1.1230 - val_accuracy: 0.5167
# Epoch 62/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1034 - accuracy: 0.5349 - val_loss: 1.1349 - val_accuracy: 0.5133
# Epoch 63/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.0896 - accuracy: 0.5401 - val_loss: 1.1265 - val_accuracy: 0.5427
# Epoch 64/300
# 218/218 [==============================] - 4s 17ms/step - loss: 1.0843 - accuracy: 0.5438 - val_loss: 1.1214 - val_accuracy: 0.5233
# Epoch 65/300
# 218/218 [==============================] - 4s 16ms/step - loss: 1.0671 - accuracy: 0.5497 - val_loss: 1.0969 - val_accuracy: 0.5560
# Epoch 66/300
# 218/218 [==============================] - 3s 16ms/step - loss: 1.0814 - accuracy: 0.5499 - val_loss: 1.1189 - val_accuracy: 0.5420
# Epoch 67/300
# 218/218 [==============================] - 4s 16ms/step - loss: 1.0717 - accuracy: 0.5481 - val_loss: 1.1129 - val_accuracy: 0.5360
# Epoch 68/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0546 - accuracy: 0.5588 - val_loss: 1.0998 - val_accuracy: 0.5433
# Epoch 69/300
# 218/218 [==============================] - 4s 18ms/step - loss: 1.0620 - accuracy: 0.5580 - val_loss: 1.0800 - val_accuracy: 0.5533
# Epoch 70/300
# 218/218 [==============================] - 4s 21ms/step - loss: 1.0663 - accuracy: 0.5489 - val_loss: 1.0990 - val_accuracy: 0.5447
# Epoch 71/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.0496 - accuracy: 0.5599 - val_loss: 1.1018 - val_accuracy: 0.5387
# Epoch 72/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.0557 - accuracy: 0.5576 - val_loss: 1.0706 - val_accuracy: 0.5533
# Epoch 73/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0468 - accuracy: 0.5648 - val_loss: 1.0730 - val_accuracy: 0.5513
# Epoch 74/300
# 218/218 [==============================] - 4s 19ms/step - loss: 1.0447 - accuracy: 0.5595 - val_loss: 1.0773 - val_accuracy: 0.5633
# Epoch 75/300
# 218/218 [==============================] - 4s 21ms/step - loss: 1.0337 - accuracy: 0.5678 - val_loss: 1.0836 - val_accuracy: 0.5333
# Epoch 76/300
# 218/218 [==============================] - 4s 21ms/step - loss: 1.0378 - accuracy: 0.5684 - val_loss: 1.0935 - val_accuracy: 0.5400
# Epoch 77/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0417 - accuracy: 0.5661 - val_loss: 1.0704 - val_accuracy: 0.5420
# Epoch 78/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0417 - accuracy: 0.5693 - val_loss: 1.0646 - val_accuracy: 0.5447
# Epoch 79/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0237 - accuracy: 0.5750 - val_loss: 1.0777 - val_accuracy: 0.5553
# Epoch 80/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0249 - accuracy: 0.5718 - val_loss: 1.0508 - val_accuracy: 0.5520
# Epoch 81/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0184 - accuracy: 0.5812 - val_loss: 1.0363 - val_accuracy: 0.5647
# Epoch 82/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.0273 - accuracy: 0.5797 - val_loss: 1.0472 - val_accuracy: 0.5660
# Epoch 83/300
# 218/218 [==============================] - 5s 21ms/step - loss: 1.0167 - accuracy: 0.5747 - val_loss: 1.0501 - val_accuracy: 0.5860
# Epoch 84/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0095 - accuracy: 0.5818 - val_loss: 1.0527 - val_accuracy: 0.5727
# Epoch 85/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0083 - accuracy: 0.5828 - val_loss: 1.0386 - val_accuracy: 0.5820
# Epoch 86/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0197 - accuracy: 0.5861 - val_loss: 1.0454 - val_accuracy: 0.5860
# Epoch 87/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0047 - accuracy: 0.5881 - val_loss: 1.0340 - val_accuracy: 0.5860
# Epoch 88/300
# 218/218 [==============================] - 5s 22ms/step - loss: 1.0063 - accuracy: 0.5835 - val_loss: 1.0407 - val_accuracy: 0.5960
# Epoch 89/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0022 - accuracy: 0.5920 - val_loss: 1.0376 - val_accuracy: 0.5800
# Epoch 90/300
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0046 - accuracy: 0.5876 - val_loss: 1.0434 - val_accuracy: 0.5900
# Epoch 91/300
# 218/218 [==============================] - 5s 22ms/step - loss: 0.9912 - accuracy: 0.6006 - val_loss: 1.0176 - val_accuracy: 0.5947
# Epoch 92/300
# 218/218 [==============================] - 5s 21ms/step - loss: 0.9924 - accuracy: 0.5999 - val_loss: 1.0404 - val_accuracy: 0.5927
# Epoch 93/300
# 218/218 [==============================] - 5s 23ms/step - loss: 0.9896 - accuracy: 0.5899 - val_loss: 1.0068 - val_accuracy: 0.6153
# Epoch 94/300
# 218/218 [==============================] - 5s 22ms/step - loss: 0.9786 - accuracy: 0.5964 - val_loss: 1.0426 - val_accuracy: 0.5907
# Epoch 95/300
# 218/218 [==============================] - 5s 23ms/step - loss: 0.9884 - accuracy: 0.5872 - val_loss: 1.0124 - val_accuracy: 0.6040
# Epoch 96/300
# 218/218 [==============================] - 5s 22ms/step - loss: 0.9791 - accuracy: 0.6072 - val_loss: 0.9926 - val_accuracy: 0.6300
# Epoch 97/300
# 218/218 [==============================] - 5s 22ms/step - loss: 0.9804 - accuracy: 0.6029 - val_loss: 0.9836 - val_accuracy: 0.6160
# Epoch 98/300
# 218/218 [==============================] - 5s 23ms/step - loss: 0.9846 - accuracy: 0.5984 - val_loss: 0.9963 - val_accuracy: 0.6253
# Epoch 99/300
# 218/218 [==============================] - 5s 21ms/step - loss: 0.9781 - accuracy: 0.6032 - val_loss: 0.9836 - val_accuracy: 0.6167
# Epoch 100/300
# 218/218 [==============================] - 4s 20ms/step - loss: 0.9682 - accuracy: 0.6068 - val_loss: 0.9796 - val_accuracy: 0.6147
# Epoch 101/300
# 218/218 [==============================] - 4s 20ms/step - loss: 0.9578 - accuracy: 0.6020 - val_loss: 1.0031 - val_accuracy: 0.6133
# Epoch 102/300
# 218/218 [==============================] - 5s 21ms/step - loss: 0.9683 - accuracy: 0.6029 - val_loss: 0.9792 - val_accuracy: 0.6140
# Epoch 103/300
# 218/218 [==============================] - 4s 20ms/step - loss: 0.9623 - accuracy: 0.6085 - val_loss: 0.9793 - val_accuracy: 0.6173
# Epoch 104/300
# 218/218 [==============================] - 4s 20ms/step - loss: 0.9616 - accuracy: 0.6072 - val_loss: 0.9802 - val_accuracy: 0.6327
# Epoch 105/300
# 218/218 [==============================] - 4s 20ms/step - loss: 0.9547 - accuracy: 0.6167 - val_loss: 0.9580 - val_accuracy: 0.6393
# Epoch 106/300
# 218/218 [==============================] - 5s 21ms/step - loss: 0.9646 - accuracy: 0.6105 - val_loss: 0.9857 - val_accuracy: 0.6400
# Epoch 107/300
# 218/218 [==============================] - 5s 21ms/step - loss: 0.9492 - accuracy: 0.6190 - val_loss: 0.9879 - val_accuracy: 0.6300
# Epoch 108/300
# 218/218 [==============================] - 5s 23ms/step - loss: 0.9591 - accuracy: 0.6132 - val_loss: 0.9767 - val_accuracy: 0.6327
# Epoch 109/300
# 218/218 [==============================] - 4s 19ms/step - loss: 0.9446 - accuracy: 0.6270 - val_loss: 0.9817 - val_accuracy: 0.6340
# Epoch 110/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9468 - accuracy: 0.6236 - val_loss: 0.9757 - val_accuracy: 0.6407
# Epoch 111/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9489 - accuracy: 0.6249 - val_loss: 0.9646 - val_accuracy: 0.6487
# Epoch 112/300
# 218/218 [==============================] - 4s 17ms/step - loss: 0.9383 - accuracy: 0.6243 - val_loss: 0.9495 - val_accuracy: 0.6260
# Epoch 113/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9535 - accuracy: 0.6182 - val_loss: 0.9793 - val_accuracy: 0.6267
# Epoch 114/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9296 - accuracy: 0.6241 - val_loss: 0.9803 - val_accuracy: 0.6347
# Epoch 115/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9436 - accuracy: 0.6218 - val_loss: 0.9634 - val_accuracy: 0.6420
# Epoch 116/300
# 218/218 [==============================] - 4s 17ms/step - loss: 0.9371 - accuracy: 0.6250 - val_loss: 0.9427 - val_accuracy: 0.6453
# Epoch 117/300
# 218/218 [==============================] - 4s 16ms/step - loss: 0.9474 - accuracy: 0.6247 - val_loss: 0.9496 - val_accuracy: 0.6413
# Epoch 118/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9300 - accuracy: 0.6326 - val_loss: 0.9386 - val_accuracy: 0.6353
# Epoch 119/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9343 - accuracy: 0.6302 - val_loss: 0.9493 - val_accuracy: 0.6567
# Epoch 120/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9243 - accuracy: 0.6286 - val_loss: 0.9657 - val_accuracy: 0.6167
# Epoch 121/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9270 - accuracy: 0.6305 - val_loss: 0.9552 - val_accuracy: 0.6300
# Epoch 122/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9106 - accuracy: 0.6368 - val_loss: 0.9246 - val_accuracy: 0.6493
# Epoch 123/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9208 - accuracy: 0.6375 - val_loss: 0.9530 - val_accuracy: 0.6427
# Epoch 124/300
# 218/218 [==============================] - 3s 15ms/step - loss: 0.9099 - accuracy: 0.6450 - val_loss: 0.9408 - val_accuracy: 0.6547
# Epoch 125/300
# 218/218 [==============================] - 4s 17ms/step - loss: 0.9307 - accuracy: 0.6295 - val_loss: 0.9364 - val_accuracy: 0.6653
# Epoch 126/300
# 218/218 [==============================] - 4s 17ms/step - loss: 0.9206 - accuracy: 0.6401 - val_loss: 0.9563 - val_accuracy: 0.6293
# Epoch 127/300
# 218/218 [==============================] - 4s 16ms/step - loss: 0.9230 - accuracy: 0.6368 - val_loss: 0.9367 - val_accuracy: 0.6527
# Epoch 128/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.8971 - accuracy: 0.6466 - val_loss: 0.9319 - val_accuracy: 0.6507
# Epoch 129/300
# 218/218 [==============================] - 4s 16ms/step - loss: 0.9179 - accuracy: 0.6290 - val_loss: 0.9162 - val_accuracy: 0.6300
# Epoch 130/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9115 - accuracy: 0.6384 - val_loss: 0.9593 - val_accuracy: 0.6407
# Epoch 131/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9241 - accuracy: 0.6376 - val_loss: 0.9414 - val_accuracy: 0.6493
# Epoch 132/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9076 - accuracy: 0.6389 - val_loss: 0.8978 - val_accuracy: 0.6480
# Epoch 133/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9062 - accuracy: 0.6405 - val_loss: 0.9173 - val_accuracy: 0.6527
# Epoch 134/300
# 218/218 [==============================] - 4s 16ms/step - loss: 0.9042 - accuracy: 0.6425 - val_loss: 0.9245 - val_accuracy: 0.6380
# Epoch 135/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9038 - accuracy: 0.6417 - val_loss: 0.9278 - val_accuracy: 0.6553
# Epoch 136/300
# 218/218 [==============================] - 4s 16ms/step - loss: 0.9033 - accuracy: 0.6448 - val_loss: 0.9263 - val_accuracy: 0.6453
# Epoch 137/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.8883 - accuracy: 0.6494 - val_loss: 0.9494 - val_accuracy: 0.6440
# Epoch 138/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9078 - accuracy: 0.6438 - val_loss: 0.9439 - val_accuracy: 0.6347
# Epoch 139/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9025 - accuracy: 0.6430 - val_loss: 0.9153 - val_accuracy: 0.6607
# Epoch 140/300
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9047 - accuracy: 0.6420 - val_loss: 0.9382 - val_accuracy: 0.6313
# Epoch 141/300
#  46/218 [=====>........................] - ETA: 2s - loss: 0.8862 - accuracy: 0.6522

# %% [markdown]
# ## (vi)(CNN-Attention) Visualizing the accuracy and loss trajectory

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['accuracy'])
plt.plot(hybrid_cnn_lstm_model_results.history['val_accuracy'])
plt.title('CNN-MHA model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_lstm_model_results.history['val_loss'],'o')
plt.title('CNN-MHA model model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## (vii)(CNN-LSTM) Testing the performance of the hybrid CNN-LSTM model on the held out test set

# %%
## Testing the hybrid CNN-LSTM model

hybrid_cnn_lstm_score = hybrid_cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hybrid CNN-MHA model:',hybrid_cnn_lstm_score[1])
# Out:
# Test accuracy of the hybrid CNN-attention model: 0.6715575456619263
